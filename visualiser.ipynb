# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import numpy as np

# %%
df = pd.read_csv("simulation/Results.csv").to_numpy(dtype=np.float64)

# %%
# Get x coordinates from file
xearth = []
yearth = []
zearth = []

xsun = []
ysun = []
zsun = []

energy = []
for i in df:
    xearth.append(i[2])
    yearth.append(i[3])
    zearth.append(i[4])

    xsun.append(i[6])
    ysun.append(i[7])
    zsun.append(i[8])
    energy.append(i[0])
    
energy_difference = df[len(df)-1][0] - df[0][0] 
energy_percent_difference = (energy_difference / df[0][0]) * 100
print(energy_percent_difference)
# Out:
# 4.593847825941942e-05

# %%
plt.plot(x)

# %%
plt.plot(energy)

# %%
# Work out distance between earth and sun over time

distance = []

for i in range(0,len(xearth)):
    distance.append(np.sqrt((xearth[i] - xsun[i])**2 + (yearth[i] - ysun[i])**2 + (zearth[i] - zsun[i])**2))
